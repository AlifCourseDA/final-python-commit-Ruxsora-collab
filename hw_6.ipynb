# %%
import pandas as pd
df = pd.read_csv('transaction_data.csv')
df
# Out:
#                      date                name  transaction
# 0     2020-03-02 00:37:20   Ekaterina_Petrova    cancelled
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 3     2020-03-02 00:02:58    Lolita_Polyanova    cancelled
# 4     2020-03-02 00:17:52      Julia_Smirnova    cancelled
# ...                   ...                 ...          ...
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull
# 5314  2020-03-02 01:15:45      Irina_Fedorova    cancelled
#
# [5315 rows x 3 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from datetime import datetime

# %%
df.isna()
# Out:
#        date   name  transaction
# 0     False  False        False
# 1     False  False        False
# 2     False  False        False
# 3     False  False        False
# 4     False  False        False
# ...     ...    ...          ...
# 5310  False  False        False
# 5311  False  False        False
# 5312  False  False        False
# 5313  False  False        False
# 5314  False  False        False
#
# [5315 rows x 3 columns]

# %%
# Пропущенных значений нет

# %%
# В колонке transaction есть значений successfull and cancelled

# %%
specific_values = ['successfull']

successfull = df[df["transaction"].isin(specific_values)]
print(successfull)
# Out:
#                      date                name  transaction
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 6     2020-03-02 00:54:12        Olga_Lesnova  successfull
# 7     2020-03-02 00:18:43       Irina_Lesnova  successfull
# 8     2020-03-02 00:06:10    Vasilisa_Petrova  successfull
# ...                   ...                 ...          ...
# 5309  2020-03-02 01:26:13        Olga_Ozerova  successfull
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull
#
# [3692 rows x 3 columns]

# %%
other_value = ['cancelled']

df[df['transaction'].isin(other_value)]
# Out:
#                      date                 name transaction
# 0     2020-03-02 00:37:20    Ekaterina_Petrova   cancelled
# 3     2020-03-02 00:02:58     Lolita_Polyanova   cancelled
# 4     2020-03-02 00:17:52       Julia_Smirnova   cancelled
# 5     2020-03-02 01:09:55      Irina_Polyanova   cancelled
# 13    2020-03-02 01:04:03     Lolita_Polyanova   cancelled
# ...                   ...                  ...         ...
# 5288  2020-03-02 01:03:58        Masha_Lesnova   cancelled
# 5290  2020-03-02 00:24:16   Vasilisa_Polyanova   cancelled
# 5291  2020-03-02 01:27:11  Ekaterina_Polyanova   cancelled
# 5299  2020-03-02 00:07:20         Olga_Ozerova   cancelled
# 5314  2020-03-02 01:15:45       Irina_Fedorova   cancelled
#
# [1619 rows x 3 columns]

# %%
# 1620 транзакций завершились ошибкой
# 3692 транзакций завершились успешно

# %%
df['transaction'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='transaction'>

# %%
tran = df.drop_duplicates(subset="name")
print(tran)
# Out:
#                     date                 name  transaction
# 0    2020-03-02 00:37:20    Ekaterina_Petrova    cancelled
# 1    2020-03-02 00:59:09       Irina_Fedorova  successfull
# 2    2020-03-02 01:06:14   Ekaterina_Smirnova  successfull
# 3    2020-03-02 00:02:58     Lolita_Polyanova    cancelled
# 4    2020-03-02 00:17:52       Julia_Smirnova    cancelled
# 5    2020-03-02 01:09:55      Irina_Polyanova    cancelled
# 6    2020-03-02 00:54:12         Olga_Lesnova  successfull
# 7    2020-03-02 00:18:43        Irina_Lesnova  successfull
# 8    2020-03-02 00:06:10     Vasilisa_Petrova  successfull
# 9    2020-03-02 00:47:06         Olga_Petrova  successfull
# 10   2020-03-02 01:20:50       Irina_Smirnova  successfull
# 11   2020-03-02 00:45:16   Vasilisa_Polyanova  successfull
# 12   2020-03-02 01:01:48        Masha_Ozerova  successfull
# 14   2020-03-02 00:22:27       Masha_Fedorova  successfull
# 15   2020-03-02 01:28:21       Lolita_Ivanova  successfull
# ...

# %%
unique = df.groupby("name")["transaction"].sum()
print(unique)
# Out:
# name
# Ekaterina_Fedorova     cancelledcancelledsuccessfullsuccessfullsucces...
# Ekaterina_Ivanova      successfullsuccessfullsuccessfullsuccessfullsu...
# Ekaterina_Lesnova      successfullsuccessfullsuccessfullcancelledsucc...
# Ekaterina_Ozerova      cancelledsuccessfullsuccessfullsuccessfullsucc...
# Ekaterina_Petrova      cancelledsuccessfullsuccessfullsuccessfullcanc...
# Ekaterina_Polyanova    successfullsuccessfullsuccessfullcancelledsucc...
# Ekaterina_Smirnova     successfullsuccessfullsuccessfullcancelledsucc...
# Irina_Fedorova         successfullsuccessfullsuccessfullcancelledcanc...
# Irina_Ivanova          successfullsuccessfullcancelledsuccessfullcanc...
# Irina_Lesnova          successfullsuccessfullsuccessfullsuccessfullsu...
# Irina_Ozerova          successfullcancelledsuccessfullsuccessfullcanc...
# Irina_Petrova          successfullsuccessfullsuccessfullsuccessfullsu...
# Irina_Polyanova        cancelledcancelledsuccessfullsuccessfullcancel...
# ...

# %%
tran["transaction"].value_counts()
# Out:
# transaction
# successfull    43
# cancelled      13
# Name: count, dtype: int64

# %%
df = pd.read_csv('transaction_data_updated.csv')

# %%
df
# Out:
#                      date                name  transaction  minute
# 0     2020-03-02 00:37:20   Ekaterina_Petrova    cancelled      37
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull      59
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull       6
# 3     2020-03-02 00:02:58    Lolita_Polyanova    cancelled       2
# 4     2020-03-02 00:17:52      Julia_Smirnova    cancelled      17
# ...                   ...                 ...          ...     ...
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull       9
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull      46
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull      16
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull      13
# 5314  2020-03-02 01:15:45      Irina_Fedorova    cancelled      15
#
# [5315 rows x 4 columns]

# %%
df.isna()
# Out:
#        date   name  transaction  minute
# 0     False  False        False   False
# 1     False  False        False   False
# 2     False  False        False   False
# 3     False  False        False   False
# 4     False  False        False   False
# ...     ...    ...          ...     ...
# 5310  False  False        False   False
# 5311  False  False        False   False
# 5312  False  False        False   False
# 5313  False  False        False   False
# 5314  False  False        False   False
#
# [5315 rows x 4 columns]

# %%
# пропущенных значений нет

# %%
df['transaction'].isna().any()
# Out:
# False

# %%
# Ошибки нет нигде
